# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
import easyocr
import cv2
from matplotlib import pyplot as plt
import numpy as np

image = 'bw_image2.jpeg'
reader = easyocr.Reader(['en'])
result = reader.readtext(image,paragraph="False")
result
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# [W NNPACK.cpp:51] Could not initialize NNPACK! Reason: Unsupported hardware.
# [[[[81, 450], [686, 450], [686, 767], [81, 767]],
#   'KrIshna Footwcir Mr  Surcnder Kumar Baluk Ihabarmal Gu": Dehrd On Sone Rohtash (IIIIAR) Plu No 82 1307 Mob: Nu 7654200020']]

# %%
top_left = tuple(result[0][0][0])
bottom_right = tuple(result[0][0][2])
text = result[0][1]
font = cv2.FONT_HERSHEY_SIMPLEX
img = cv2.imread(image)
spacer = 100
for detection in result: 
    top_left = tuple(detection[0][0])
    bottom_right = tuple(detection[0][2])
    text = detection[1]
    img = cv2.rectangle(img,top_left,bottom_right,(0,255,0),3)
    img = cv2.putText(img,text,(20,spacer), font, 0.4,(0,255,0),2,cv2.LINE_AA)
    spacer+=35

plt.figure(figsize=(10,10))
print(text)
plt.imshow(img)
plt.show()
# Out:
# KrIshna Footwcir Mr  Surcnder Kumar Baluk Ihabarmal Gu": Dehrd On Sone Rohtash (IIIIAR) Plu No 82 1307 Mob: Nu 7654200020

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
import easyocr
import cv2
from matplotlib import pyplot as plt
import numpy as np

image = 'image2.jpeg'
reader = easyocr.Reader(['en'])
result = reader.readtext(image,paragraph="False")
result
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# [[[[0, 440], [47, 440], [47, 470], [0, 470]], 'rO'],
#  [[[81, 455], [684, 455], [684, 766], [81, 766]],
#   'Kshms Tootiei Ar Sureuder Kumar Baluja halyasmal Gali Dehri On Sone Rohtash (BSHIAR) Pau No 021307 Mol. No. 7654200020'],
#  [[[0, 899], [499, 899], [499, 1018], [0, 1018]], '8 COAPORATION C tenua V']]

# %%
top_left = tuple(result[0][0][0])
bottom_right = tuple(result[0][0][2])
text = result[0][1]
font = cv2.FONT_HERSHEY_SIMPLEX
img = cv2.imread(image)
spacer = 100
for detection in result: 
    top_left = tuple(detection[0][0])
    bottom_right = tuple(detection[0][2])
    text = detection[1]
    print(text)
    img = cv2.rectangle(img,top_left,bottom_right,(0,255,0),3)
    img = cv2.putText(img,text,(20,spacer), font, 0.5,(0,255,0),2,cv2.LINE_AA)
    spacer+=35

plt.figure(figsize=(10,10))
plt.imshow(img)
plt.show()
# Out:
# rO
# Kshms Tootiei Ar Sureuder Kumar Baluja halyasmal Gali Dehri On Sone Rohtash (BSHIAR) Pau No 021307 Mol. No. 7654200020
# 8 COAPORATION C tenua V
