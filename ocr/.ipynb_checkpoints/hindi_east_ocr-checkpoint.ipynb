# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
import easyocr
import cv2
from matplotlib import pyplot as plt
import numpy as np
from IPython.display import Image
import time

# %%
#----------Method-1---------- "just one word"

start = time.time()
image = 'hindi1.png'
reader = easyocr.Reader(['en','hi'])
result = reader.readtext(image,paragraph="False")
result

top_left = tuple(result[0][0][0])
bottom_right = tuple(result[0][0][2])
text = result[0][1]
font = cv2.FONT_HERSHEY_SIMPLEX
img = cv2.imread(image)
spacer = 45
for detection in result: 
    top_left = tuple(detection[0][0])
    bottom_right = tuple(detection[0][2])
    text = detection[1]
    img = cv2.rectangle(img,top_left,bottom_right,(0,255,0),3)
    img = cv2.putText(img,text,(15,spacer), font, 0.4,(0,255,0),2,cv2.LINE_AA)
    spacer+=35

plt.figure(figsize=(10,10))
print("\n\n\nDetected text: " + text)
plt.imshow(img)
plt.show()
out = str(time.time()-start)
print("time taken to detect text: " + out)
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# [W NNPACK.cpp:51] Could not initialize NNPACK! Reason: Unsupported hardware.
# Detected text: हिन्दी
# time taken to detect text: 5.545423746109009

# %%
#----------Method-2---------- "more than one words"

start = time.time()
image = 'hindi_page.png'
reader = easyocr.Reader(['en', 'hi'])
result = reader.readtext(image,paragraph="False")
result

top_left = tuple(result[0][0][0])
bottom_right = tuple(result[0][0][2])
text = result[0][1]
font = cv2.FONT_HERSHEY_SIMPLEX
img = cv2.imread(image)
spacer = 25
for detection in result: 
    top_left = tuple(detection[0][0])
    bottom_right = tuple(detection[0][2])
    text = detection[1]
    print("\nDetected text: " + text)
    img = cv2.rectangle(img,top_left,bottom_right,(0,255,0),3)
    img = cv2.putText(img,text,(10,spacer), font, 0.5,(0,255,0),2,cv2.LINE_AA)
    spacer+=35

plt.figure(figsize=(10,10))
plt.imshow(img)
plt.show()
out = str(time.time()-start)
print("time taken to detect text: " + out)
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# Detected text: आपके
#
# Detected text: अवचेतन मन की शक्त
#
# Detected text: डॉ॰ जोसेफ़ मर्फ़ी डीआर. एस.,पीएच.डी.
#
# Detected text: अनुवादक : डॉ. सुधीर दीक्षित. रजनी दीक्षित
#
# Detected text: MANJUL
#
# Detected text: मंजुल पब्लिशिंग हाउस
# time taken to detect text: 47.1394829750061

# %%
#----------Method-1---------- "just one word"

start = time.time()
image = 'hp1.png'
reader = easyocr.Reader(['en','hi'])
result = reader.readtext(image,paragraph="False")
result

top_left = tuple(result[0][0][0])
bottom_right = tuple(result[0][0][2])
text = result[0][1]
font = cv2.FONT_HERSHEY_SIMPLEX
img = cv2.imread(image)
spacer = 45
for detection in result: 
    top_left = tuple(detection[0][0])
    bottom_right = tuple(detection[0][2])
    text = detection[1]
    img = cv2.rectangle(img,top_left,bottom_right,(0,255,0),3)
    img = cv2.putText(img,text,(15,spacer), font, 0.4,(0,255,0),2,cv2.LINE_AA)
    spacer+=35

plt.figure(figsize=(10,10))
print("\n\n\nDetected text: " + text)
plt.imshow(img)
plt.show()
out = str(time.time()-start)
print("time taken to detect text: " + out)
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# Detected text: बनने क लिए आपको इसक सिद्धांतों को॰ समझना होगा| तभी आपः इसकी शक्तियों का इस्तमाल करते समय जानः पाएँगें कि आपको कौन से परिणाम मि्लेंगे| आप जिन विशिष्ट लकष्यों को हासिल क़रना चाहते हैं, उन्हें आपं इन शक्तियों की मदद से साकार कर सकते हैं| केॅई   सालों तक   मैंने केमिस्ट   का काम   किया या॰ अपने   शुरुआती प्रशिक्षण में मैंने यह सीखा कि जब आप हाइड्रोजन॰.कें दो परंमाणुओं और ऑक्सीजन कें एक परमाणु को मिलाते हैं, तों परिणाम हमेंशा पांनी होता है कभी ्कभार या अक्सर नहीं, हमेशा| ज़ब आप ऑक्सीजन क एक परमाणु और कार्बन के एक परमाणु को मिलाते हैं, तो कार्बन मोनोऑक्साइड नामक ज़हरीली गैस उत्पन्नः होती है| लेकिन अगर आप ऑक्सीजन काः एक और परमाणु. ज़ोड़ देते हैं॰ तो आपको कार्बन डाइऑक्साइड मिल जाती है॰ जो प्राणियों के लिए हानिरहित और पौधों के लिए जीवनदायी होती है॰ ये शाश्वत और अपरिवर्तनीय तय्य हैं॰ इन्हें हम सिद्धांत कहते हैं| काम करने की॰ दृष्टि से आपके अवचेतन मन क सिद्धांत केमिस्ट्री , फ़िज़िक्स और गणित क सिद्धांतों से अलग. नहीं हैं| अगर आप रासायनिक या ` भौतिक   शक्तियों का प्रयोग करना चाहते हैं, तो आपको इनं क्षेत्रों के सिद्धांतों को सीखना होगा| इसी तरह अगर आप अपने अवचेतन मन की शक्ति का प्रयोग करना चाहते हैं॰ तो आपको इसक सिद्धांतों को सीखनाः होगा| आम तौर पर इस सिद्धांत को सभी स्वीकार करते हैं पानी अपंना स्तर ख्रुद खोज लेता है| यह एक शाश्वत सिद्धांत हैॅ यह हर जगह, हर समय पानी और पानी जैसे सभी द्रवों पर लागू होता हैl प्राचीन मिस्र के लोग इंस सिद्धांत को जानते थे| इसका प्रयोग़ उन्होने महान पिरामिंडों की नींव को आदर्श रूंप से संमतलं बनाने ्में किया थातं आज भीं सिंचाई तंत्र से लेकर हाइड्रो इलेक्ट्रिक पॉवर स्टेशन बनाते समयं इंजीनियर इसका प्रयोग करते हैं| या यह सिद्धांत लें : गर्म होने पर पदार्य फैलता है| यह हर जगह , हर समय और हर परिस्थिति में सच है| अगर आप स्टील के टुकड़े को गर्म करेंगे , तो यह फैलेगा, चाहे यह स्टील चीन, इंग्लैंड, भारत में हो या पृथ्वी का चक्क़र लगा रहे अंतरिक्ष यान में हो| गर्म होने पर पदार्थ फैलता है॰... यह एक शाश्वत सत्य है| यह भी एक
# time taken to detect text: 211.33270406723022

# %%
#----------Method-2---------- "paragraphs"

start = time.time()
image = 'hp1.png'
reader = easyocr.Reader(['en', 'hi'])
result = reader.readtext(image,paragraph="False")
result

top_left = tuple(result[0][0][0])
bottom_right = tuple(result[0][0][2])
text = result[0][1]
font = cv2.FONT_HERSHEY_SIMPLEX
img = cv2.imread(image)
spacer = 25
for detection in result: 
    top_left = tuple(detection[0][0])
    bottom_right = tuple(detection[0][2])
    text = detection[1]
    print("\nDetected text: " + text)
    img = cv2.rectangle(img,top_left,bottom_right,(0,255,0),3)
    img = cv2.putText(img,text,(10,spacer), font, 0.5,(0,255,0),2,cv2.LINE_AA)
    spacer+=35

plt.figure(figsize=(10,10))
plt.imshow(img)
plt.show()
out = str(time.time()-start)
print("time taken to detect text: " + out)
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# Detected text: 24
#
# Detected text: आपके अवचेतन मन की शक्ति
#
# Detected text: बनने क लिए आपको इसक सिद्धांतों को॰ समझना होगा| तभी आपः इसकी शक्तियों का इस्तमाल करते समय जानः पाएँगें कि आपको कौन से परिणाम मि्लेंगे| आप जिन विशिष्ट लकष्यों को हासिल क़रना चाहते हैं, उन्हें आपं इन शक्तियों की मदद से साकार कर सकते हैं| केॅई   सालों तक   मैंने केमिस्ट   का काम   किया या॰ अपने   शुरुआती प्रशिक्षण में मैंने यह सीखा कि जब आप हाइड्रोजन॰.कें दो परंमाणुओं और ऑक्सीजन कें एक परमाणु को मिलाते हैं, तों परिणाम हमेंशा पांनी होता है कभी ्कभार या अक्सर नहीं, हमेशा| ज़ब आप ऑक्सीजन क एक परमाणु और कार्बन के एक परमाणु को मिलाते हैं, तो कार्बन मोनोऑक्साइड नामक ज़हरीली गैस उत्पन्नः होती है| लेकिन अगर आप ऑक्सीजन काः एक और परमाणु. ज़ोड़ देते हैं॰ तो आपको कार्बन डाइऑक्साइड मिल जाती है॰ जो प्राणियों के लिए हानिरहित और पौधों के लिए जीवनदायी होती है॰ ये शाश्वत और अपरिवर्तनीय तय्य हैं॰ इन्हें हम सिद्धांत कहते हैं| काम करने की॰ दृष्टि से आपके अवचेतन मन क सिद्धांत केमिस्ट्री , फ़िज़िक्स और गणित क सिद्धांतों से अलग. नहीं हैं| अगर आप रासायनिक या ` भौतिक   शक्तियों का प्रयोग करना चाहते हैं, तो आपको इनं क्षेत्रों के सिद्धांतों को सीखना होगा| इसी तरह अगर आप अपने अवचेतन मन की शक्ति का प्रयोग करना चाहते हैं॰ तो आपको इसक सिद्धांतों को सीखनाः होगा| आम तौर पर इस सिद्धांत को सभी स्वीकार करते हैं पानी अपंना स्तर ख्रुद खोज लेता है| यह एक शाश्वत सिद्धांत हैॅ यह हर जगह, हर समय पानी और पानी जैसे सभी द्रवों पर लागू होता हैl प्राचीन मिस्र के लोग इंस सिद्धांत को जानते थे| इसका प्रयोग़ उन्होने महान पिरामिंडों की नींव को आदर्श रूंप से संमतलं बनाने ्में किया थातं आज भीं सिंचाई तंत्र से लेकर हाइड्रो इलेक्ट्रिक पॉवर स्टेशन बनाते समयं इंजीनियर इसका प्रयोग करते हैं| या यह सिद्धांत लें : गर्म होने पर पदार्य फैलता है| यह हर जगह , हर समय और हर परिस्थिति में सच है| अगर आप स्टील के टुकड़े को गर्म करेंगे , तो यह फैलेगा, चाहे यह स्टील चीन, इंग्लैंड, भारत में हो या पृथ्वी का चक्क़र लगा रहे अंतरिक्ष यान में हो| गर्म होने पर पदार्थ फैलता है॰... यह एक शाश्वत सत्य है| यह भी एक
# time taken to detect text: 209.5259621143341

# %%
#----------Method-2---------- "paragraphs"

start = time.time()
image = 'hp2.png'
reader = easyocr.Reader(['en', 'hi'])
result = reader.readtext(image,paragraph="False")
result

top_left = tuple(result[0][0][0])
bottom_right = tuple(result[0][0][2])
text = result[0][1]
font = cv2.FONT_HERSHEY_SIMPLEX
img = cv2.imread(image)
spacer = 25
for detection in result: 
    top_left = tuple(detection[0][0])
    bottom_right = tuple(detection[0][2])
    text = detection[1]
    print("\nDetected text: " + text)
    img = cv2.rectangle(img,top_left,bottom_right,(0,255,0),3)
    img = cv2.putText(img,text,(10,spacer), font, 0.5,(0,255,0),2,cv2.LINE_AA)
    spacer+=35

plt.figure(figsize=(10,10))
plt.imshow(img)
plt.show()
out = str(time.time()-start)
print("time taken to detect text: " + out)
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# Detected text: आपका अवचेतन मानसिक अवरोघ कैेसे हटाता है
#
# Detected text: 247
#
# Detected text: ज़िम्मेदारियों से पलायन करने की कोशिश कर रहे हैं॰ शराबी क रूप रमें आपकीः कोई स्वतंत्र इच्छा नहीं है, हालाँकि आप साोच सकते हैं कि है| हो सकता है आप अपनी इच्छाशक्ति के बारे में डोंगें होँकते हों: अगर आप आदतन शराबी हैं औंर साहस क साथ यह घोषणा करते हैं, *अब मैं इसे कभी नही छुऊँगा " तो आपर्में इस घोषणा को सही साबित करने की शक्ति नहीं है| कारण यह है कि आप यह नहीं जानते हैं कि शक्ति को कहाँ   खोजना है| दरअसल आप ख्रुद की बनाई मनोवैज्ञानिक जेल में रह रहे हैं| आप अपनें विश्वासों , रार्यों, प्रशिक्षण और माहौल के प्रभावों की बेड़ि्यों में जकड़े हुए हैं| अधिकांश लोगों की तरह आप. भी आदत क ग़ुलाम हैं| आप जिस तरह से प्रतिक़्रिया क़रते हैं॰ उसके लिए कंडीशन्ड हैं|
#
# Detected text: स्वतंत्रता केःविचार बनाना आपः अपनी मानसिकता में स्वतंत्रता और मानसिक शाति का विचार भर सकते हैं॰ ताकिं यह आपकी अवचेतन   गहराइयों ततक पहुँच जाए अवचेतन मन सर्वशक्तिमान है, इसलिए यहं आपकों शराब पीने की इच्छा से मुक्त कर देगा| उसें मोड़ पर आपको एक नई समझ मिलेगीं कि आपका  दिमाग़ कैसे काम करता है| आपको अपने भोतर असीमित संसाधन मिलेंगे , जिनक द्वारा आप अपनी बात को सच साबित कर सकते हैं|
#
# Detected text: डक्यावन प्रतिशत उपचार अंगर आपके मन में किसी विनाशक आदत से छुटकारा पाने की प्रबल इच्छा हैरतो आपका इक्यावन प्रतिशत इलाज पहले ही हो चुका है| जब आपकी बुरी अंदत को छोड़ने की इच्छा इसे जारी रखने की आवश्यकता से अधिक बड़ी हा जाती है, तो आपको यह जानकर हैरानी होगी कि पूर्ण स्वतंत्रता सिर्फ़ एक क़दम दूर है| जो भी विचार आप अपने दिमाग़ में लंगर की तरह डालते हैं, आपका मस्तिष्क उसका विस्तार करता   है॰ मस्तिष्क को स्वत्तंत्रता  की अवधारणा यानी , विनाशक आदत से छुटकारा और मानसिक शॉति पर केद्रित करें॰ इसे
# time taken to detect text: 185.55750703811646

# %%
#----------Method-2---------- "paragraphs"

start = time.time()
image = 'hp3.png'
reader = easyocr.Reader(['en', 'hi'])
result = reader.readtext(image,paragraph="False")
result

top_left = tuple(result[0][0][0])
bottom_right = tuple(result[0][0][2])
text = result[0][1]
font = cv2.FONT_HERSHEY_SIMPLEX
img = cv2.imread(image)
spacer = 25
for detection in result: 
    top_left = tuple(detection[0][0])
    bottom_right = tuple(detection[0][2])
    text = detection[1]
    print("\nDetected text: " + text)
    img = cv2.rectangle(img,top_left,bottom_right,(0,255,0),3)
    img = cv2.putText(img,text,(10,spacer), font, 0.5,(0,255,0),2,cv2.LINE_AA)
    spacer+=35

plt.figure(figsize=(10,10))
plt.imshow(img)
plt.show()
out = str(time.time()-start)
print("time taken to detect text: " + out)
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# Detected text: आपका अवचेतन मानसिक अवरोघ कैसे हटाता है
#
# Detected text: 241
#
# Detected text: उपकी मानसिक तस्वीर की शकित बॉब ने अपने   शरीर को शिथिल  करने का अभ्यास किया और मनन की निष्रिय अवस्था में पहुँच गया| फिर उसने यह जानते हुए मस्तिष्क में इच्छित परिणाम की तस्वीर भरी कि उसका अवचेतन मन सबसे आसान तरीक़े से इसे साकार कर सकता है| उसने कल्पना की॰कि उसकी बेटी गले लगते हुए स्वागत कर रही है और क़ह रही है॰ " ओह डैडी, कितना अच्छा हुआ कि आप दोबारा घर   लौट आए!॰ नियमित रूप से॰ सुनियोजित तरीक़े से वह इस तरहं से बैठकर मनन करता रहा| ध्यान भटकने पर उसने तत्कालं अपनी बेटी की मानसिक तस्वीर यांद करने की आदत डाल ली॰ उसकी मुस्कान के साय और उसके घर का दृश्य, जो बेटी की चहकती आवाज़ से जीवंत था| इस सबसे उसके दिमाग़ की दोबारा कडीशनिंग हो गई| यह एक क्रमिक प्रक्रिया थी॰ उसने इसे जारी रखा॰ व़ह लेंगा रहा, क्योकिं वह जानता या कि देर-्सबेर वह अपने अवचेतन मन में आदत का नया पैटर्न बंना   लेेगा| मैंने उसे बताया कि वह अपने चेतन म़न को कैमरे की तरह मान सकता है, जबकि उसका अवचेतन ःमन वह संवेदनशील प्लेट है, जिस पर वह तस्वीर की छाप छोड़ता है| इस सुझाव का उस पर गहरा प्रभाव पड़ा  उसका   पूरा लक्ष्य यह बनः गया कि वह अपने मन की तस्वीर की दृढ़ छाप छोड़़े और उसे डेवलपं करे॰ फ़िल्म को अँधेरे में डेवलप किया जात हैः इसी तरह मानसिक तस्वीरों को अवचेतन मन के ड़ार्क़ रूम में डेवलप किया जाता है|
#
# Detected text: केंद्रित ध्यान बॉब समझ गया कि उसका चेतन मन कैमरे की तरह है॰ इसलिए उसने कोई कीशिश   नंहीं की॰ कोई मानसिक संघर्ष नहीं हुआ| उसने शाति से अपने विचारों को संतुलित किया और अपना ध्यान अपने सामने के दृश्य पर केद्रित क़िंया , जंब तक कि वह तस्वीर क साय क्रमशः एकाकार नहीं हो गया| वह मानसिक माहौल में डूब गया और मानसिक फ़िल्म को बारःबार देखने. लगा| उपचार होने कें बारे में कोई शंका ही नहीं थी| जब भी पीने की तलब लगती थी, तो वह अपनी कल्पना को शराब के विचार से दूर मोड़कर अपने परिवार के साय घर पर रहने की भावना की ओर मोड़ लेता या| वहं सफल
# time taken to detect text: 207.21836304664612
